# %% [markdown]
# # Using Geopy to Get Hospital Coordinatees
# ### By Brian Minie (bminie7@gmail.com)
#
# In this notebook, I'll demonstrate how to use Geopy to get a hospitals latitude and longitude. Due to the long runtime of this notebook (we are looking up >5000 hospitals), we will write the results to a CSV file so they can be used in other steps/notebooks.
#
# In the future, we could envision these steps as part of a pipeline where the data is pulled down and refreshed on a regular basis.

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from geopy.extra.rate_limiter import RateLimiter
from geopy.geocoders import Photon

# %%
hospital_general_info_df = pd.read_csv("data/Hospital_General_Info.csv")
hospital_general_info_df["full_address"] = hospital_general_info_df.address + " " + hospital_general_info_df.city + "," + hospital_general_info_df.state + " " + hospital_general_info_df.zip_code.astype(str)
subset_df = hospital_general_info_df[["facility_id", "facility_name", "address", "city", "state", "zip_code", "full_address"]]

# %%
locator = Photon(user_agent="myGeocoder")
# 1 - conveneint function to delay between geocoding calls
geocode = RateLimiter(locator.geocode, min_delay_seconds=1)
# 2- - create location column
subset_df['location'] = subset_df['facility_name'].apply(geocode)
# 3 - create longitude, laatitude and altitude from location column (returns tuple)
subset_df['point'] = subset_df['location'].apply(lambda loc: tuple(loc.point) if loc else None)
# Out:
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('ORLANDO HEALTH-HEALTH CENTRAL HOSPITAL',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\http\client.py", line 1369, in getresponse
#     response.begin()
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\http\client.py", line 310, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\http\client.py", line 271, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\ssl.py", line 1071, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\ssl.py", line 929, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 706, in urlopen
#     chunked=chunked,
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 447, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 337, in _raise_timeout
#     self, url, "Read timed out. (read timeout=%s)" % timeout_value
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='photon.komoot.io', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 756, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\util\retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='photon.komoot.io', port=443): Max retries exceeded with url: /api?q=ORLANDO+HEALTH-HEALTH+CENTRAL+HOSPITAL&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='photon.komoot.io', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\adapters.py", line 448, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\sessions.py", line 555, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='photon.komoot.io', port=443): Max retries exceeded with url: /api?q=ORLANDO+HEALTH-HEALTH+CENTRAL+HOSPITAL&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='photon.komoot.io', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\geocoders\photon.py", line 167, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\adapters.py", line 438, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\adapters.py", line 460, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='photon.komoot.io', port=443): Max retries exceeded with url: /api?q=ORLANDO+HEALTH-HEALTH+CENTRAL+HOSPITAL&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='photon.komoot.io', port=443): Read timed out. (read timeout=1)"))
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('NOBLE HEALTH AUDRAIN COMMUNITY HOSPITAL',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\http\client.py", line 1369, in getresponse
#     response.begin()
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\http\client.py", line 310, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\http\client.py", line 271, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\ssl.py", line 1071, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\ssl.py", line 929, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 706, in urlopen
#     chunked=chunked,
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 447, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 337, in _raise_timeout
#     self, url, "Read timed out. (read timeout=%s)" % timeout_value
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='photon.komoot.io', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 756, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\util\retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='photon.komoot.io', port=443): Max retries exceeded with url: /api?q=NOBLE+HEALTH+AUDRAIN+COMMUNITY+HOSPITAL&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='photon.komoot.io', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\adapters.py", line 448, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\sessions.py", line 555, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='photon.komoot.io', port=443): Max retries exceeded with url: /api?q=NOBLE+HEALTH+AUDRAIN+COMMUNITY+HOSPITAL&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='photon.komoot.io', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\geocoders\photon.py", line 167, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\adapters.py", line 438, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\adapters.py", line 460, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='photon.komoot.io', port=443): Max retries exceeded with url: /api?q=NOBLE+HEALTH+AUDRAIN+COMMUNITY+HOSPITAL&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='photon.komoot.io', port=443): Read timed out. (read timeout=1)"))
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('SOUTHEASTHEALTH CENTER OF STODDARD COUNTY',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\http\client.py", line 1369, in getresponse
#     response.begin()
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\http\client.py", line 310, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\http\client.py", line 271, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\ssl.py", line 1071, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\ssl.py", line 929, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 706, in urlopen
#     chunked=chunked,
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 447, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 337, in _raise_timeout
#     self, url, "Read timed out. (read timeout=%s)" % timeout_value
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='photon.komoot.io', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 756, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\util\retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='photon.komoot.io', port=443): Max retries exceeded with url: /api?q=SOUTHEASTHEALTH+CENTER+OF+STODDARD+COUNTY&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='photon.komoot.io', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\adapters.py", line 448, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\sessions.py", line 555, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='photon.komoot.io', port=443): Max retries exceeded with url: /api?q=SOUTHEASTHEALTH+CENTER+OF+STODDARD+COUNTY&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='photon.komoot.io', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\geocoders\photon.py", line 167, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\adapters.py", line 438, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\adapters.py", line 460, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='photon.komoot.io', port=443): Max retries exceeded with url: /api?q=SOUTHEASTHEALTH+CENTER+OF+STODDARD+COUNTY&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='photon.komoot.io', port=443): Read timed out. (read timeout=1)"))
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('AVERA ST BENEDICT HEALTH CENTER - CAH',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connection.py", line 170, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\util\connection.py", line 96, in create_connection
#     raise err
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\util\connection.py", line 86, in create_connection
#     sock.connect(sa)
# socket.timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 706, in urlopen
#     chunked=chunked,
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 382, in _make_request
#     self._validate_conn(conn)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 1010, in _validate_conn
#     conn.connect()
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connection.py", line 353, in connect
#     conn = self._new_conn()
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connection.py", line 177, in _new_conn
#     % (self.host, self.timeout),
# urllib3.exceptions.ConnectTimeoutError: (<urllib3.connection.HTTPSConnection object at 0x0000017E48A52C08>, 'Connection to photon.komoot.io timed out. (connect timeout=1)')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 756, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\util\retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='photon.komoot.io', port=443): Max retries exceeded with url: /api?q=AVERA+ST+BENEDICT+HEALTH+CENTER+-+CAH&limit=1 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000017E48A52C08>, 'Connection to photon.komoot.io timed out. (connect timeout=1)'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\adapters.py", line 448, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\sessions.py", line 555, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\adapters.py", line 504, in send
#     raise ConnectTimeout(e, request=request)
# requests.exceptions.ConnectTimeout: HTTPSConnectionPool(host='photon.komoot.io', port=443): Max retries exceeded with url: /api?q=AVERA+ST+BENEDICT+HEALTH+CENTER+-+CAH&limit=1 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000017E48A52C08>, 'Connection to photon.komoot.io timed out. (connect timeout=1)'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\geocoders\photon.py", line 167, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\adapters.py", line 438, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\adapters.py", line 460, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='photon.komoot.io', port=443): Max retries exceeded with url: /api?q=AVERA+ST+BENEDICT+HEALTH+CENTER+-+CAH&limit=1 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000017E48A52C08>, 'Connection to photon.komoot.io timed out. (connect timeout=1)'))
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('CORPUS CHRISTI MEDICAL CENTER,THE',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\http\client.py", line 1369, in getresponse
#     response.begin()
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\http\client.py", line 310, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\http\client.py", line 271, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\ssl.py", line 1071, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\ssl.py", line 929, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 706, in urlopen
#     chunked=chunked,
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 447, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 337, in _raise_timeout
#     self, url, "Read timed out. (read timeout=%s)" % timeout_value
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='photon.komoot.io', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 756, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\util\retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='photon.komoot.io', port=443): Max retries exceeded with url: /api?q=CORPUS+CHRISTI+MEDICAL+CENTER%2CTHE&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='photon.komoot.io', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\adapters.py", line 448, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\sessions.py", line 555, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='photon.komoot.io', port=443): Max retries exceeded with url: /api?q=CORPUS+CHRISTI+MEDICAL+CENTER%2CTHE&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='photon.komoot.io', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\geocoders\photon.py", line 167, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\adapters.py", line 438, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\adapters.py", line 460, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='photon.komoot.io', port=443): Max retries exceeded with url: /api?q=CORPUS+CHRISTI+MEDICAL+CENTER%2CTHE&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='photon.komoot.io', port=443): Read timed out. (read timeout=1)"))
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('THROCKMORTON COUNTY MEMORIAL HOSPITAL',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\http\client.py", line 1369, in getresponse
#     response.begin()
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\http\client.py", line 310, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\http\client.py", line 271, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\ssl.py", line 1071, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\ssl.py", line 929, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 706, in urlopen
#     chunked=chunked,
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 447, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 337, in _raise_timeout
#     self, url, "Read timed out. (read timeout=%s)" % timeout_value
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='photon.komoot.io', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 756, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\util\retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='photon.komoot.io', port=443): Max retries exceeded with url: /api?q=THROCKMORTON+COUNTY+MEMORIAL+HOSPITAL&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='photon.komoot.io', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\adapters.py", line 448, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\sessions.py", line 555, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='photon.komoot.io', port=443): Max retries exceeded with url: /api?q=THROCKMORTON+COUNTY+MEMORIAL+HOSPITAL&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='photon.komoot.io', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\geocoders\photon.py", line 167, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\adapters.py", line 438, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\adapters.py", line 460, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='photon.komoot.io', port=443): Max retries exceeded with url: /api?q=THROCKMORTON+COUNTY+MEMORIAL+HOSPITAL&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='photon.komoot.io', port=443): Read timed out. (read timeout=1)"))
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('ELECTRA MEMORIAL HOSPITAL',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\http\client.py", line 1369, in getresponse
#     response.begin()
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\http\client.py", line 310, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\http\client.py", line 271, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\ssl.py", line 1071, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\ssl.py", line 929, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 706, in urlopen
#     chunked=chunked,
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 447, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 337, in _raise_timeout
#     self, url, "Read timed out. (read timeout=%s)" % timeout_value
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='photon.komoot.io', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 756, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\util\retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='photon.komoot.io', port=443): Max retries exceeded with url: /api?q=ELECTRA+MEMORIAL+HOSPITAL&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='photon.komoot.io', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\adapters.py", line 448, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\sessions.py", line 555, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='photon.komoot.io', port=443): Max retries exceeded with url: /api?q=ELECTRA+MEMORIAL+HOSPITAL&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='photon.komoot.io', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\geocoders\photon.py", line 167, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\adapters.py", line 438, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\adapters.py", line 460, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='photon.komoot.io', port=443): Max retries exceeded with url: /api?q=ELECTRA+MEMORIAL+HOSPITAL&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='photon.komoot.io', port=443): Read timed out. (read timeout=1)"))
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('ODESSA MEMORIAL HEALTHCARE CENTER',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\http\client.py", line 1369, in getresponse
#     response.begin()
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\http\client.py", line 310, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\http\client.py", line 271, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\ssl.py", line 1071, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\ssl.py", line 929, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 706, in urlopen
#     chunked=chunked,
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 447, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 337, in _raise_timeout
#     self, url, "Read timed out. (read timeout=%s)" % timeout_value
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='photon.komoot.io', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\connectionpool.py", line 756, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\urllib3\util\retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='photon.komoot.io', port=443): Max retries exceeded with url: /api?q=ODESSA+MEMORIAL+HEALTHCARE+CENTER&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='photon.komoot.io', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\adapters.py", line 448, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\sessions.py", line 555, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='photon.komoot.io', port=443): Max retries exceeded with url: /api?q=ODESSA+MEMORIAL+HEALTHCARE+CENTER&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='photon.komoot.io', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\geocoders\photon.py", line 167, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\adapters.py", line 438, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\geopy\adapters.py", line 460, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='photon.komoot.io', port=443): Max retries exceeded with url: /api?q=ODESSA+MEMORIAL+HEALTHCARE+CENTER&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='photon.komoot.io', port=443): Read timed out. (read timeout=1)"))
# C:\Users\bmini\anaconda3\envs\jupyter\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
geo_df = pd.DataFrame(subset_df['point'].tolist(), index=subset_df.facility_id, columns=['latitude', 'longitude', 'altitude'])
subset_df.set_index("facility_id", inplace=True)
complete = pd.merge(subset_df, geo_df, left_index=True, right_index=True)
complete.to_csv("data/hospital_coordinates.csv")
